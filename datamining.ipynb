# %%
# Dependencies
import requests
import json
import pandas as pd
import query
import time

pd.set_option('display.max_columns', None)

# %%
def getResponse(variables):
    """ function to get a response from the API, returns pandas dataframe with page data """
    try: 
        response = requests.post(query.url, json={'query': query.query, 'variables': variables})
    except requests.exceptions.HTTPError as err:
        print(err.response.status_code)
        print(err.response.text)
        
    """ load the response into a json object """
    data = json.loads(response.content)
    
    try:
        
        """ save the hasNextPage feature to determine further data extraction from API """
        page_flag = data['data']['Page']['pageInfo']['hasNextPage']
        
        """ convert json into a dataframe """
        df = pd.json_normalize(data, record_path =['data', 'Page', 'media'])
        
    except(TypeError) as err:
        """ Error output """
        page_flag = False
        df = pd.DataFrame()
        
    return page_flag, df

# %%
def flipping_pages(variables, flag = True):
    """ function to keep making post requests as long as there are pages to be mined """
    start = time.time()
    df = pd.DataFrame()
    while flag:
        flag, data = getResponse(variables)
        df = pd.concat([df, data])
        print(f"Page {variables['page']} has been registered into the dataframe.")
        variables['page'] +=1
    end = time.time()
    print(f"Data mining the API completed after: {end-start} sec.")
    return df

# %%
data =  flipping_pages(query.variables)
# Out:
# Page 1 has been registered into the dataframe.
# Page 2 has been registered into the dataframe.
# Page 3 has been registered into the dataframe.
# Page 4 has been registered into the dataframe.
# Page 5 has been registered into the dataframe.
# Page 6 has been registered into the dataframe.
# Page 7 has been registered into the dataframe.
# Page 8 has been registered into the dataframe.
# Page 9 has been registered into the dataframe.
# Page 10 has been registered into the dataframe.
# Page 11 has been registered into the dataframe.
# Page 12 has been registered into the dataframe.
# Page 13 has been registered into the dataframe.
# Page 14 has been registered into the dataframe.
# Page 15 has been registered into the dataframe.
# Page 16 has been registered into the dataframe.
# Page 17 has been registered into the dataframe.
# Page 18 has been registered into the dataframe.
# Page 19 has been registered into the dataframe.
# Page 20 has been registered into the dataframe.
# Page 21 has been registered into the dataframe.
# Page 22 has been registered into the dataframe.
# Page 23 has been registered into the dataframe.
# Page 24 has been registered into the dataframe.
# Page 25 has been registered into the dataframe.
# Page 26 has been registered into the dataframe.
# Page 27 has been registered into the dataframe.
# Page 28 has been registered into the dataframe.
# Page 29 has been registered into the dataframe.
# Page 30 has been registered into the dataframe.
# Page 31 has been registered into the dataframe.
# Page 32 has been registered into the dataframe.
# Page 33 has been registered into the dataframe.
# Page 34 has been registered into the dataframe.
# Page 35 has been registered into the dataframe.
# Page 36 has been registered into the dataframe.
# Page 37 has been registered into the dataframe.
# Page 38 has been registered into the dataframe.
# Page 39 has been registered into the dataframe.
# Page 40 has been registered into the dataframe.
# Page 41 has been registered into the dataframe.
# Page 42 has been registered into the dataframe.
# Page 43 has been registered into the dataframe.
# Page 44 has been registered into the dataframe.
# Page 45 has been registered into the dataframe.
# Page 46 has been registered into the dataframe.
# Page 47 has been registered into the dataframe.
# Page 48 has been registered into the dataframe.
# Page 49 has been registered into the dataframe.
# Page 50 has been registered into the dataframe.
# Page 51 has been registered into the dataframe.
# Page 52 has been registered into the dataframe.
# Page 53 has been registered into the dataframe.
# Page 54 has been registered into the dataframe.
# Page 55 has been registered into the dataframe.
# Page 56 has been registered into the dataframe.
# Page 57 has been registered into the dataframe.
# Page 58 has been registered into the dataframe.
# Page 59 has been registered into the dataframe.
# Page 60 has been registered into the dataframe.
# Page 61 has been registered into the dataframe.
# Page 62 has been registered into the dataframe.
# Page 63 has been registered into the dataframe.
# Page 64 has been registered into the dataframe.
# Page 65 has been registered into the dataframe.
# Page 66 has been registered into the dataframe.
# Page 67 has been registered into the dataframe.
# Page 68 has been registered into the dataframe.
# Page 69 has been registered into the dataframe.
# Page 70 has been registered into the dataframe.
# Page 71 has been registered into the dataframe.
# Page 72 has been registered into the dataframe.
# Page 73 has been registered into the dataframe.
# Page 74 has been registered into the dataframe.
# Page 75 has been registered into the dataframe.
# Page 76 has been registered into the dataframe.
# Page 77 has been registered into the dataframe.
# Page 78 has been registered into the dataframe.
# Page 79 has been registered into the dataframe.
# Page 80 has been registered into the dataframe.
# Page 81 has been registered into the dataframe.
# Page 82 has been registered into the dataframe.
# Page 83 has been registered into the dataframe.
# Page 84 has been registered into the dataframe.
# Page 85 has been registered into the dataframe.
# Page 86 has been registered into the dataframe.
# Page 87 has been registered into the dataframe.
# Page 88 has been registered into the dataframe.
# Page 89 has been registered into the dataframe.
# Page 90 has been registered into the dataframe.
# Page 91 has been registered into the dataframe.
# Data mining the API completed after: 52.94020891189575 sec.

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4500 entries, 0 to 49
# Data columns (total 16 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   id               4500 non-null   int64
#  1   status           4500 non-null   object
#  2   genres           4500 non-null   object
#  3   description      4500 non-null   object
#  4   averageScore     2205 non-null   float64
#  5   popularity       4500 non-null   int64
#  6   siteUrl          4500 non-null   object
#  7   title.english    2069 non-null   object
#  8   title.native     4008 non-null   object
#  9   title.romaji     4500 non-null   object
#  10  startDate.year   4017 non-null   float64
#  11  startDate.month  2769 non-null   float64
#  12  startDate.day    2579 non-null   float64
#  13  endDate.year     3011 non-null   float64
#  14  endDate.month    2591 non-null   float64
#  15  endDate.day      2413 non-null   float64
# dtypes: float64(7), int64(2), object(7)
# memory usage: 597.7+ KB

# %%
data.shape
# Out:
# (4500, 16)

# %%
data.head()
# Out:
#       id     status                                             genres  \
# 0  30001   FINISHED          [Drama, Mystery, Psychological, Thriller]
# 1  30002  RELEASING  [Action, Adventure, Drama, Fantasy, Horror, Ps...
# 2  30003   FINISHED  [Drama, Mystery, Psychological, Sci-Fi, Thriller]
# 3  30004   FINISHED                            [Sci-Fi, Slice of Life]
# 4  30007  RELEASING                    [Action, Comedy, Drama, Sports]
#
#                                          description  averageScore  \
# 0  Everyone faces uncertainty at some point in th...          90.0
# 1  His name is Guts, the Black Swordsman, a feare...          93.0
# 2  Humanity, having faced extinction at the end o...          88.0
# 3  Set hundreds of years in the future after an e...          86.0
# 4  Makunouchi Ippo has been bullied his entire li...          86.0
#
#    popularity                         siteUrl            title.english  \
# 0       59580  https://anilist.co/manga/30001                  Monster
# 1      133510  https://anilist.co/manga/30002                  Berserk
# 2       55697  https://anilist.co/manga/30003        20th Century Boys
# 3       21509  https://anilist.co/manga/30004  Yokohama Kaidashi Kikou
# 4       18911  https://anilist.co/manga/30007                     None
#
#   title.native             title.romaji  startDate.year  startDate.month  \
# 0      MONSTER                  MONSTER          1994.0             12.0
# 1        ベルセルク                  Berserk          1989.0              8.0
# 2       20世紀少年        20th Century Boys          1999.0              9.0
# 3   ヨコハマ買い出し紀行  Yokohama Kaidashi Kikou          1994.0              4.0
# 4       はじめの一歩           Hajime no Ippo          1989.0              9.0
#
#    startDate.day  endDate.year  endDate.month  endDate.day
# 0            5.0        2001.0           12.0         20.0
# 1           25.0           NaN            NaN          NaN
# 2           27.0        2006.0            4.0         24.0
# 3           26.0        2006.0            2.0         26.0
# 4           27.0           NaN            NaN          NaN

# %%
# Save the dataframe into csv (out_data.csv)
data.to_csv('out_data.csv', index = False)
